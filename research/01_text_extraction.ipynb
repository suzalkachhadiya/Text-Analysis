# %%
import os

# %%
# %pwd
# Out:
# 'c:\\DataScience\\Projects\\Text_analysis\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\DataScience\\Projects\\Text_analysis'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class TextExtractionConfig:
    root_dir: Path
    input_file: Path
    destination_folder: Path

# %%
from src.text_analysis.constants import *
from src.text_analysis.utils.common import read_yaml_file, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH):
        # params_filepath = PARAMS_FILE_PATH):
        # schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml_file(config_filepath)
        # self.params = read_yaml_file(params_filepath)
        # self.schema = read_yaml_file(schema_filepath)

        create_directories([self.config.artifacts_root])


    def get_text_extraction_config(self) -> TextExtractionConfig:
        config = self.config.text_extraction

        create_directories([config.root_dir])

        data_ingestion_config = TextExtractionConfig(
            root_dir=config.root_dir,
            input_file=config.input_file,
            destination_folder=config.destination_folder
        )

        return data_ingestion_config

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
class TextExtraction:
    def __init__(self, config: TextExtractionConfig):
        self.config = config

    def extract_text(self):
        
        df=pd.read_excel(self.config.input_file)
        
        url_list=list(df["URL"])
        url_id_list=list(df["URL_ID"])

        for id, url in zip(url_id_list,url_list):
            print(id,url)

            response=requests.get(url,headers=HEADERS)
            html_content=response.text

            soup=BeautifulSoup(html_content,"html.parser")

            for ele in soup.find_all(["script","style","nav","footer","header","aside"]):
                ele.decompose()

            article_selectors=[
                "article",
                "[class*='article']",
                "[class*='post']",
                "main",
                ".content",
                "#content"
            ]

            title=""
            title_tag=soup.find("h1") or soup.find("title")
            if title_tag:
                title=title_tag.get_text().strip()

            article_content=None
            for selector in article_selectors:
                article_content=soup.select_one(selector)
                if article_content:
                    break
            text=article_content.get_text(separator="\n",strip=True)

            # Create filename from title or timestamp
            filename = id
            filename = f"artifacts/text_extraction/{filename}.txt"

            with open(filename, 'w', encoding='utf-8') as file:
                file.write(f"Title: {id}\n")
                file.write(f"Source URL: {url}\n")
                file.write("=" * 50 + "\n\n")
                file.write(text)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_text_extraction_config()
    data_ingestion = TextExtraction(config=data_ingestion_config)
    data_ingestion.extract_text()
except Exception as e:
    raise e
# Out:
# [2024-11-14 17:38:52,135: INFO:common: yaml file: config\config.yaml loaded successfully]
# [2024-11-14 17:38:52,135: INFO:common: createD Directory at:artifacts]
# [2024-11-14 17:38:52,135: INFO:common: createD Directory at:artifacts/text_extraction]
# Netclan20241017 https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Netclan20241018 https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Netclan20241019 https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Netclan20241020 https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Netclan20241021 https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/
# Netclan20241022 https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Netclan20241023 https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Netclan20241024 https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Netclan20241025 https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Netclan20241026 https://insights.blackcoffer.com/transforming-and-managing-a-large-scale-sql-pedigree-database-to-neo4j-graph-db/
# Netclan20241027 https://insights.blackcoffer.com/enhancing-model-accuracy-from-58-to-over-90-strategies-for-improving-predictive-performance/
# Netclan20241028 https://insights.blackcoffer.com/securing-sensitive-financial-data-with-privacy-preserving-machine-learning-for-predictive-analytics/
# Netclan20241029 https://insights.blackcoffer.com/enhancing-data-collection-for-research-institutions-addressing-survey-fatigue-and-incorporating-verbal-communication-for-richer-insights/
# Netclan20241030 https://insights.blackcoffer.com/analyzing-the-impact-of-positive-emotions-and-pandemic-severity-on-mental-health-and-resilience-among-entrepreneurs-insights-and-predictive-modeling/
# Netclan20241031 https://insights.blackcoffer.com/dynamic-brand-centric-dashboard-for-automotive-dealerships-pdf-to-financial-insights-with-flask-react-architecture-and-aws-cloud-hosting/
# Netclan20241032 https://insights.blackcoffer.com/cloud-based-data-modeling-and-analysis-platform-with-drag-and-drop-interface-and-openai-api-integration-for-simulation-insights/
# Netclan20241033 https://insights.blackcoffer.com/voter-profile-analysis-and-search-application-for-targeted-campaign-engagement-using-government-voter-data/
# Netclan20241034 https://insights.blackcoffer.com/bert-based-classification-of-individuals-and-organizations-into-two-categories-using-natural-language-processing/
# Netclan20241035 https://insights.blackcoffer.com/comprehensive-analysis-of-solana-and-ethereum-contributors-using-github-api-with-comparative-study-of-1000-random-github-profiles/
# Netclan20241036 https://insights.blackcoffer.com/powerbi-rest-api-fetching-dataflow-and-refresh-schedules-with-semantic-models/
# Netclan20241037 https://insights.blackcoffer.com/automated-job-data-import-and-management-solution-for-enhanced-efficiency/
# Netclan20241038 https://insights.blackcoffer.com/data-analytics-and-optimization-solution-for-enhancing-renewable-energy-efficiency/
# Netclan20241039 https://insights.blackcoffer.com/time-series-analysis-and-trend-forecasting-solution-for-predicting-news-trends/
# Netclan20241040 https://insights.blackcoffer.com/advanced-data-visualization-solutions-for-monitoring-key-business-metrics-with-integrated-interactive-dashboards/
# Netclan20241041 https://insights.blackcoffer.com/advanced-patient-data-analysis-solution-for-trend-identification-and-improved-healthcare-outcome/
# Netclan20241042 https://insights.blackcoffer.com/anomaly-detection-and-analysis-for-enhanced-data-integrity-and-user-experience-on-bright-datas-website/
# Netclan20241043 https://insights.blackcoffer.com/building-custom-tflite-models-and-benchmarking-on-voxl2-chips/
# Netclan20241044 https://insights.blackcoffer.com/sports-prediction-model-for-multiple-sports-leagues/
# Netclan20241045 https://insights.blackcoffer.com/efficient-coach-allocation-system-for-sports-coaching-organization/
# Netclan20241046 https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function-2/
# Netclan20241047 https://insights.blackcoffer.com/ai-driven-backend-for-audio-to-text-conversion-and-analytical-assessment-in-pharmaceutical-practice/
# Netclan20241048 https://insights.blackcoffer.com/cloud-based-web-application-for-financial-data-processing-and-visualization-of-sp-500-metrics/
# Netclan20241049 https://insights.blackcoffer.com/department-wise-kpi-tracking-dashboard-with-technician-performance-analysis-for-atoz-dependable-service/
# Netclan20241050 https://insights.blackcoffer.com/steps-to-convert-a-node-js-api-to-python-for-aws-lambda-deployment/
# Netclan20241051 https://insights.blackcoffer.com/building-an-analytics-dashboard-with-a-pdf-parsing-pipeline-for-data-extraction/
# Netclan20241052 https://insights.blackcoffer.com/building-a-real-time-log-file-visualization-dashboard-in-kibana/
# Netclan20241053 https://insights.blackcoffer.com/analyzing-the-impact-of-female-ceo-appointments-on-company-stock-prices/
# Netclan20241054 https://insights.blackcoffer.com/ai-chatbot-using-llm-langchain-llama/
# Netclan20241055 https://insights.blackcoffer.com/healthcare-ai-chatbot-using-llama-llm-langchain/
# Netclan20241056 https://insights.blackcoffer.com/ai-bot-audio-to-audio/
# Netclan20241057 https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/
# Netclan20241058 https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/
# Netclan20241059 https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/
# Netclan20241060 https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/
# Netclan20241061 https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/
# Netclan20241062 https://insights.blackcoffer.com/data-management-for-a-political-saas-application/
# Netclan20241063 https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/
# Netclan20241064 https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/
# Netclan20241065 https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/
# Netclan20241066 https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/
# Netclan20241067 https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/
# Netclan20241068 https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/
# Netclan20241069 https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/
# Netclan20241070 https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/
# Netclan20241071 https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/
# Netclan20241072 https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/
# Netclan20241073 https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/
# Netclan20241074 https://insights.blackcoffer.com/advanced-ai-for-trading-automation/
# Netclan20241075 https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/
# Netclan20241076 https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/
# Netclan20241077 https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/
# Netclan20241078 https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/
# Netclan20241079 https://insights.blackcoffer.com/handgun-detection-using-yolo/
# Netclan20241080 https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/
# Netclan20241081 https://insights.blackcoffer.com/car-detection-in-satellite-images/
# Netclan20241082 https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/
# Netclan20241083 https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/
# Netclan20241084 https://insights.blackcoffer.com/data-transformation/
# Netclan20241085 https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/
# Netclan20241086 https://insights.blackcoffer.com/kpi-dashboard-for-accountants/
# Netclan20241087 https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/
# Netclan20241088 https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/
# Netclan20241089 https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/
# Netclan20241090 https://insights.blackcoffer.com/trading-bot-for-forex/
# Netclan20241091 https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/
# Netclan20241092 https://insights.blackcoffer.com/medical-classification/
# Netclan20241093 https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/
# Netclan20241094 https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/
# Netclan20241095 https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/
# Netclan20241096 https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/
# Netclan20241097 https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/
# Netclan20241098 https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/
# Netclan20241099 https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/
# Netclan20241100 https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/
# Netclan20241101 https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/
# Netclan20241102 https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/
# Netclan20241103 https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/
# Netclan20241104 https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/
# Netclan20241105 https://insights.blackcoffer.com/web-data-connector/
# Netclan20241106 https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/
# Netclan20241107 https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/
# Netclan20241108 https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/
# Netclan20241109 https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/
# Netclan20241110 https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/
# Netclan20241111 https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/
# Netclan20241112 https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/
# Netclan20241113 https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/
# Netclan20241114 https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/
# Netclan20241115 https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/
# Netclan20241116 https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/
# Netclan20241117 https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/
# Netclan20241118 https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/
# Netclan20241119 https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/
# Netclan20241120 https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/
# Netclan20241121 https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/
# Netclan20241122 https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/
# Netclan20241123 https://insights.blackcoffer.com/metabridges-api-decentraland-integration/
# Netclan20241124 https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/
# Netclan20241125 https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/
# Netclan20241126 https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/
# Netclan20241127 https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/
# Netclan20241128 https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/
# Netclan20241129 https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/
# Netclan20241130 https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/
# Netclan20241131 https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/
# Netclan20241132 https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/
# Netclan20241133 https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/
# Netclan20241134 https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/
# Netclan20241135 https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/
# Netclan20241136 https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/
# Netclan20241137 https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/
# Netclan20241138 https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/
# Netclan20241139 https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/
# Netclan20241140 https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/
# Netclan20241141 https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/
# Netclan20241142 https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/
# Netclan20241143 https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/
# Netclan20241144 https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/
# Netclan20241145 https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/
# Netclan20241146 https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/
# Netclan20241147 https://insights.blackcoffer.com/real-estate-data-warehouse/
# Netclan20241148 https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/
# Netclan20241149 https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/
# Netclan20241150 https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/
# Netclan20241151 https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/
# Netclan20241152 https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/
# Netclan20241153 https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/
# Netclan20241154 https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/
# Netclan20241155 https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/
# Netclan20241156 https://insights.blackcoffer.com/marbles-stimulation-using-python/
# Netclan20241157 https://insights.blackcoffer.com/stocktwits-data-structurization/
# Netclan20241158 https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/
# Netclan20241159 https://insights.blackcoffer.com/population-and-community-survey-of-america/
# Netclan20241160 https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# Netclan20241161 https://insights.blackcoffer.com/healthcare-data-analysis/
# Netclan20241162 https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# Netclan20241163 https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
